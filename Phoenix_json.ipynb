# %%
import pickle
import awkward as ak
import numpy as np
import vector
import json

# %%
mu=60
num_events=50
pt_cut=1.6 #GeV

# %%
with open("data/PhyGHT_mu"+str(mu)+"_10k_events_test_results.pkl","rb") as f:
    data = pickle.load(f)

# %%
trks = data["trks"]
isHS = trks[:,:,-1]==-1

# %%
trk_vect = vector.Array(ak.zip({"pt": trks[:,:,0],"eta": trks[:,:,1],"phi": trks[:,:,2],"m": ak.zeros_like(trks[:,:,0])}))

# %%
for i in range(30,31):
    # Initialize the structure
    data = {
        "Test": {
            "Tracks": {
                "TestTracks": []
            },
            "event number": 999,
            "run number": 999
        }
    }
    num_tracks = len(trk_vect[i])
    for j in range(num_tracks):
        if trk_vect[i][j].pt<pt_cut:
            continue
        px = trk_vect[i][j].px
        py = trk_vect[i][j].py
        pz = trk_vect[i][j].pz
    
        norm = np.sqrt(px**2+py**2+pz**2)
        scale = 10000
    
        px = px*scale/norm
        py = py*scale/norm
        pz = pz*scale/norm
        
        color = isHS[i][j]
    
        # Convert boolean to hex color
        hex_color = "0000DE" if color else "FF5E5E"
        #hex_color = "0000FF" if color else "FF6969"
        
        # Create start and end points
        start_point = [0.0, 0.0, 0.0]
        end_point = [px, py, pz]
        
        # Create the track entry with curved path
        track_entry = {
            "color": hex_color,
            "pos": [start_point, end_point]
        }
            
        # Add to the TestTracks list
        data["Test"]["Tracks"]["TestTracks"].append(track_entry)
        
        # Save to JSON file
    with open('phoenix/event_'+str(i)+'_mu'+str(mu)+'.json', 'w') as f:
        json.dump(data, f, indent=2)
